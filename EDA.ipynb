# %% [markdown]
# <div style="text-align: left; padding: 20px;">
#     <span style="color: #00847E; font-size: 25px; font-weight: bold;">𝓓𝓪𝓽𝓪 𝓛𝓸𝓪𝓭𝓲𝓷𝓰
# </span>
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Read CSV File: 
import pandas as pd
df= pd.read_csv('cleaned_data.csv')

# %% [markdown]
# <div style="text-align: left; padding: 20px;">
#     <span style="color: #00847E; font-size: 25px; font-weight: bold;">𝓼𝓱𝓸𝔀 𝓭𝓪𝓽𝓪
# </span>
# </div>

# %%
data.head()
# Out:
#    Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0  37-611-6911   22  Female       Middle        Married      Bachelor's
# 1  29-392-9296   49    Male         High        Married     High School
# 2  84-649-5117   24  Female       Middle         Single        Master's
# 3  48-980-6078   29  Female       Middle         Single        Master's
# 4  91-170-9072   33  Female       Middle        Widowed     High School
#
#   Occupation  Location     Purchase_Category  Purchase_Amount  ...  \
# 0     Middle      Évry  Gardening & Outdoors           333.80  ...
# 1       High  Huocheng      Food & Beverages           222.22  ...
# 2       High    Huzhen       Office Supplies           426.22  ...
# 3     Middle    Wiwilí       Home Appliances           101.31  ...
# 4     Middle      Nara             Furniture           211.70  ...
#
#    Customer_Satisfaction Engagement_with_Ads  Device_Used_for_Shopping  \
# ...

# %%
data.tail(20)
# Out:
#      Customer_ID  Age    Gender Income_Level Marital_Status Education_Level  \
# 980  72-694-4159   39    Female       Middle        Married      Bachelor's
# 981  10-079-8237   46    Female         High        Widowed        Master's
# 982  47-460-8015   48      Male       Middle       Divorced        Master's
# 983  06-061-0023   20    Female         High        Widowed     High School
# 984  80-487-2550   34      Male         High        Married      Bachelor's
# 985  23-617-2637   50    Female       Middle         Single        Master's
# 986  60-005-5187   25      Male       Middle         Single     High School
# 987  24-371-5870   49      Male       Middle         Single      Bachelor's
# 988  02-055-8248   25    Female         High       Divorced      Bachelor's
# 989  54-238-5459   40    Female         High        Widowed     High School
# 990  85-922-0190   19    Female         High        Widowed      Bachelor's
# ...

# %%
data.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Income_Level', 'Marital_Status',
#        'Education_Level', 'Occupation', 'Location', 'Purchase_Category',
#        'Purchase_Amount', 'Frequency_of_Purchase', 'Purchase_Channel',
#        'Brand_Loyalty', 'Product_Rating',
#        'Time_Spent_on_Product_Research(hours)', 'Social_Media_Influence',
#        'Discount_Sensitivity', 'Return_Rate', 'Customer_Satisfaction',
#        'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method',
#        'Time_of_Purchase', 'Discount_Used', 'Customer_Loyalty_Program_Member',
#        'Purchase_Intent', 'Shipping_Preference', 'Time_to_Decision'],
#       dtype='object')

# %%
data.shape
# Out:
# (1000, 28)

# %% [markdown]
#  3. 𝓢𝓽𝓪𝓽𝓲𝓼𝓽𝓲𝓬𝓪𝓵 𝓐𝓷𝓪𝓵𝔂𝓼𝓲𝓼
#
#
#
# <div style="text-align: left; padding: 20px;">
#     <span style="color: #00847E; font-size: 25px; font-weight: bold;">𝓼𝓱𝓸𝔀 𝓭𝓪𝓽𝓪
# </span>
# </div>

# %%
#Describe data: 
df.describe()
# Out:
#                Age  Purchase_Amount  Frequency_of_Purchase  Brand_Loyalty  \
# count  1000.000000      1000.000000            1000.000000    1000.000000
# mean     34.304000       275.063880               6.945000       3.026000
# std       9.353238       131.532998               3.147361       1.416803
# min      18.000000        50.710000               2.000000       1.000000
# 25%      26.000000       162.235000               4.000000       2.000000
# 50%      34.500000       276.165000               7.000000       3.000000
# 75%      42.000000       388.982500              10.000000       4.000000
# max      50.000000       498.330000              12.000000       5.000000
#
#        Product_Rating  Time_Spent_on_Product_Research(hours)  Return_Rate  \
# count     1000.000000                            1000.000000  1000.000000
# mean         3.033000                               1.013030     0.954000
# std          1.436654                               0.791802     0.810272
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 28 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Customer_ID                            1000 non-null   object
#  1   Age                                    1000 non-null   int64
#  2   Gender                                 1000 non-null   object
#  3   Income_Level                           1000 non-null   object
#  4   Marital_Status                         1000 non-null   object
#  5   Education_Level                        1000 non-null   object
#  6   Occupation                             1000 non-null   object
#  7   Location                               1000 non-null   object
#  8   Purchase_Category                      1000 non-null   object
#  9   Purchase_Amount                        1000 non-null   float64
# ...

# %%
df.describe(include='object')
# Out:
#         Customer_ID  Gender Income_Level Marital_Status Education_Level  \
# count          1000    1000         1000           1000            1000
# unique         1000       8            2              4               3
# top     37-611-6911  Female         High        Widowed      Bachelor's
# freq              1     452          515            260             341
#
#        Occupation Location Purchase_Category Purchase_Channel  \
# count        1000     1000              1000             1000
# unique          2      969                24                3
# top          High     Oslo       Electronics            Mixed
# freq          517        4                54              340
#
#        Social_Media_Influence Discount_Sensitivity Engagement_with_Ads  \
# count                    1000                 1000                1000
# unique                      3                    3                   3
# top                      High       Very Sensitive                High
# ...

# %%
df_null=df.isna().sum()
df_null[df_null>0]
# Out:
# Series([], dtype: int64)

# %%
df_null=df.isna().sum()/df.shape[0]*100
df_null[df_null>0]
# Out:
# Series([], dtype: float64)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.columns:
    print(i,':',df[i].nunique())
# Out:
# Customer_ID : 1000
# Age : 33
# Gender : 8
# Income_Level : 2
# Marital_Status : 4
# Education_Level : 3
# Occupation : 2
# Location : 969
# Purchase_Category : 24
# Purchase_Amount : 989
# Frequency_of_Purchase : 11
# Purchase_Channel : 3
# Brand_Loyalty : 5
# Product_Rating : 5
# Time_Spent_on_Product_Research(hours) : 12
# Social_Media_Influence : 3
# Discount_Sensitivity : 3
# Return_Rate : 3
# Customer_Satisfaction : 10
# Engagement_with_Ads : 3
# Device_Used_for_Shopping : 3
# Payment_Method : 5
# Time_of_Purchase : 344
# Discount_Used : 2
# Customer_Loyalty_Program_Member : 2
# Purchase_Intent : 4
# Shipping_Preference : 3
# Time_to_Decision : 14

# %%
df
# Out:
#      Customer_ID  Age  Gender Income_Level Marital_Status Education_Level  \
# 0    37-611-6911   22  Female       Middle        Married      Bachelor's
# 1    29-392-9296   49    Male         High        Married     High School
# 2    84-649-5117   24  Female       Middle         Single        Master's
# 3    48-980-6078   29  Female       Middle         Single        Master's
# 4    91-170-9072   33  Female       Middle        Widowed     High School
# ..           ...  ...     ...          ...            ...             ...
# 995  20-562-2569   44  Female         High       Divorced      Bachelor's
# 996  41-366-4205   50  Female         High         Single     High School
# 997  77-241-7621   26    Male         High        Married      Bachelor's
# 998  53-091-2176   21  Female         High        Widowed      Bachelor's
# 999  48-203-9118   21  Female       Middle         Single     High School
#
#     Occupation    Location     Purchase_Category  Purchase_Amount  ...  \
# ...

# %%
numeric_columns=df.select_dtypes(include='number').columns 
numeric_columns
# Out:
# Index(['Age', 'Purchase_Amount', 'Frequency_of_Purchase', 'Brand_Loyalty',
#        'Product_Rating', 'Time_Spent_on_Product_Research(hours)',
#        'Return_Rate', 'Customer_Satisfaction', 'Time_to_Decision'],
#       dtype='object')

# %%
categorical_columns=df.select_dtypes(include='object').columns 
categorical_columns
# Out:
# Index(['Customer_ID', 'Gender', 'Income_Level', 'Marital_Status',
#        'Education_Level', 'Occupation', 'Location', 'Purchase_Category',
#        'Purchase_Channel', 'Social_Media_Influence', 'Discount_Sensitivity',
#        'Engagement_with_Ads', 'Device_Used_for_Shopping', 'Payment_Method',
#        'Time_of_Purchase', 'Purchase_Intent', 'Shipping_Preference'],
#       dtype='object')

# %%
num_categories = df[categorical_columns].nunique()
print('number of unique categories:\n',num_categories)
# Out:
# number of unique categories:
#  Customer_ID                 1000
# Gender                         8
# Income_Level                   2
# Marital_Status                 4
# Education_Level                3
# Occupation                     2
# Location                     969
# Purchase_Category             24
# Purchase_Channel               3
# Social_Media_Influence         3
# Discount_Sensitivity           3
# Engagement_with_Ads            3
# Device_Used_for_Shopping       3
# Payment_Method                 5
# Time_of_Purchase             344
# Purchase_Intent                4
# Shipping_Preference            3
# dtype: int64

# %%
df = df.sort_values

# %%
df= pd.read_csv('cleaned_data.csv')
df.describe()
# Out:
#                Age  Purchase_Amount  Frequency_of_Purchase  Brand_Loyalty  \
# count  1000.000000      1000.000000            1000.000000    1000.000000
# mean     34.304000       275.063880               6.945000       3.026000
# std       9.353238       131.532998               3.147361       1.416803
# min      18.000000        50.710000               2.000000       1.000000
# 25%      26.000000       162.235000               4.000000       2.000000
# 50%      34.500000       276.165000               7.000000       3.000000
# 75%      42.000000       388.982500              10.000000       4.000000
# max      50.000000       498.330000              12.000000       5.000000
#
#        Product_Rating  Time_Spent_on_Product_Research(hours)  Return_Rate  \
# count     1000.000000                            1000.000000  1000.000000
# mean         3.033000                               1.013030     0.954000
# std          1.436654                               0.791802     0.810272
# ...

# %%
df= pd.read_csv('cleaned_data.csv')
df.isnull().sum()
# Out:
# Customer_ID                              0
# Age                                      0
# Gender                                   0
# Income_Level                             0
# Marital_Status                           0
# Education_Level                          0
# Occupation                               0
# Location                                 0
# Purchase_Category                        0
# Purchase_Amount                          0
# Frequency_of_Purchase                    0
# Purchase_Channel                         0
# Brand_Loyalty                            0
# Product_Rating                           0
# Time_Spent_on_Product_Research(hours)    0
# Social_Media_Influence                   0
# Discount_Sensitivity                     0
# Return_Rate                              0
# Customer_Satisfaction                    0
# Engagement_with_Ads                      0
# Device_Used_for_Shopping                 0
# Payment_Method                           0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#To show distribution data:
import seaborn as sns 
import matplotlib.pyplot as plt  
sns.histplot(df, bins=20, kde=True)
plt.show()

# %%
#Correlation Matrix:

# Select only numeric columns
numeric_df = df.select_dtypes(include=["number"])

correlation_matrix = numeric_df.corr()

print(correlation_matrix)

plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
#                                             Age  Purchase_Amount  \
# Age                                    1.000000        -0.016300
# Purchase_Amount                       -0.016300         1.000000
# Frequency_of_Purchase                 -0.045710         0.000930
# Brand_Loyalty                         -0.012910        -0.074222
# Product_Rating                         0.010427         0.015984
# Time_Spent_on_Product_Research(hours)  0.000500        -0.019524
# Return_Rate                            0.030773        -0.020808
# Customer_Satisfaction                 -0.004152        -0.022467
# Time_to_Decision                       0.004209         0.014690
#
#                                        Frequency_of_Purchase  Brand_Loyalty  \
# Age                                                -0.045710      -0.012910
# Purchase_Amount                                     0.000930      -0.074222
# Frequency_of_Purchase                               1.000000       0.014463
# ...

# %%
#Covariance:
# Select only numeric columns
numeric_df = df.select_dtypes(include=["number"])

cov_matrix = numeric_df.cov()
print(cov_matrix)

column1, column2 = "your_numeric_column1", "your_numeric_column2"
if column1 in numeric_df.columns and column2 in numeric_df.columns:
    cov_value = numeric_df[[column1, column2]].cov().iloc[0, 1]
    print(f"Covariance between {column1} and {column2}: {cov_value}")
else:
    print("Selected columns are not numeric or do not exist.")
# Out:
#                                              Age  Purchase_Amount  \
# Age                                    87.483067       -20.052652
# Purchase_Amount                       -20.052652     17300.929573
# Frequency_of_Purchase                  -1.345626         0.385109
# Brand_Loyalty                          -0.171075       -13.831773
# Product_Rating                          0.140108         3.020492
# Time_Spent_on_Product_Research(hours)   0.003703        -2.033358
# Return_Rate                             0.233217        -2.217649
# Customer_Satisfaction                  -0.111407        -8.476725
# Time_to_Decision                        0.158871         7.798156
#
#                                        Frequency_of_Purchase  Brand_Loyalty  \
# Age                                                -1.345626      -0.171075
# Purchase_Amount                                     0.385109     -13.831773
# Frequency_of_Purchase                               9.905881       0.064494
# ...

# %% [markdown]
# 4 𝓟𝓮𝓻𝓯𝓸𝓻𝓶𝓪𝓷𝓬𝓮 𝓞𝓹𝓽𝓲𝓶𝓲𝔃𝓪𝓽𝓲𝓸𝓷

# %%
#Caching DataFrame:
from joblib import Memory

memory = Memory("./cache_dir", verbose=0)

@memory.cache
def load_data():
    return pd.read_csv("cleaned_data.csv")

df = load_data()

# %%
#Repartitioning:
import dask.dataframe as dd
df = dd.read_csv("cleaned_data.csv")
df = df.repartition(npartitions=10)

# %% [markdown]
# 5.𝓔𝔁𝓹𝓵𝓸𝓻𝓪𝓽𝓸𝓻𝔂 𝓓𝓪𝓽𝓪 𝓐𝓷𝓪𝓵𝔂𝓼𝓲𝓼 𝓢𝓹𝓮𝓬𝓲𝓯𝓲𝓬𝓼

# %%
#Aggregations (sum, max, min, avg):
df_pd = df.compute()
df_pd["Age"].agg(["sum", "max", "min", "mean"])
# Out:
# sum     34304.000
# max        50.000
# min        18.000
# mean       34.304
# Name: Age, dtype: float64

# %%
#Distinct Values in a Column:
df["Age"].unique().compute()
# Out:
# 0    33
# 1    30
# 2    20
# 0    24
# 1    38
# 2    34
# 3    31
# 4    27
# 5    23
# 6    26
# 0    45
# 1    46
# 0    18
# 0    22
# 1    36
# 2    43
# 0    49
# 1    25
# 2    37
# 3    19
# 0    32
# 1    50
# 2    48
# 0    29
# 1    35
# 2    41
# 3    44
# 0    21
# 1    39
# 2    40
# 3    42
# 4    28
# 0    47
# Name: Age, dtype: int64

# %%
#Column Value Counts:
df["Age"].value_counts().compute()
# Out:
# Age
# 20    19
# 30    27
# 33    26
# 23    33
# 24    32
# 26    34
# 27    43
# 31    27
# 34    30
# 38    33
# 45    33
# 46    27
# 18    20
# 22    19
# 36    31
# 43    27
# 19    32
# 25    32
# 37    38
# 49    35
# 32    30
# 48    27
# 50    34
# 29    37
# 35    30
# 41    30
# 44    29
# 21    35
# 28    24
# 39    27
# 40    38
# 42    34
# 47    27
# Name: count, dtype: int64

# %% [markdown]
# 6.𝓦𝓸𝓻𝓴𝓲𝓷𝓰 𝔀𝓲𝓽𝓱 𝓝𝓾𝓵𝓵 𝓥𝓪𝓵𝓾𝓮𝓼

# %%
#Counting Nulls in Each Column:  
df.isnull().sum()
# Out:
# Customer_ID                              0
# Age                                      0
# Gender                                   0
# Income_Level                             0
# Marital_Status                           0
# Education_Level                          0
# Occupation                               0
# Location                                 0
# Purchase_Category                        0
# Purchase_Amount                          0
# Frequency_of_Purchase                    0
# Purchase_Channel                         0
# Brand_Loyalty                            0
# Product_Rating                           0
# Time_Spent_on_Product_Research(hours)    0
# Social_Media_Influence                   0
# Discount_Sensitivity                     0
# Return_Rate                              0
# Customer_Satisfaction                    0
# Engagement_with_Ads                      0
# Device_Used_for_Shopping                 0
# Payment_Method                           0
# ...

# %%
#Drop Rows with Null Values:
df = df.dropna()
df = df.dropna(subset=["Age", "Gender"])
df = df.dropna(how="all")

# %% [markdown]
# 7.𝓓𝓮𝓪𝓵𝓲𝓷𝓰 𝔀𝓲𝓽𝓱 𝓛𝓪𝓻𝓰𝓮 𝓓𝓪𝓽𝓪𝓼𝓮𝓽𝓼

# %%
#Sampling Data:
sampled_df = df.sample(frac=0.1, random_state=42)  # 10% sample

# %%
#Approximate Count Distinct: 
df["Age"].nunique()  # Exact distinct count
# Out:
# 33
